# %%
from pycaret.datasets import get_data
from pycaret.classification import *

# %%
iris_data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
set_up = setup(iris_data, target = 'species')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_57395c82_8c7b_11ea_8ffd_448500869c0b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_57395c82_8c7b_11ea_8ffd_448500869c0blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_57395c82_8c7b_11ea_8ffd_448500869c0brow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_57395c82_8c7b_11ea_8ffd_448500869c0brow0_col1" class="data row0 col1" >1739</td>
#             </tr>
#             <tr>
#                         <th id="T_57395c82_8c7b_11ea_8ffd_448500869c0blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_57395c82_8c7b_11ea_8ffd_448500869c0brow1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_7401df6e_8c7b_11ea_87c9_448500869c0b th {
#           text-align: left;
#     }    #T_7401df6e_8c7b_11ea_87c9_448500869c0brow0_col0 {
#             text-align:  left;
#         }    #T_7401df6e_8c7b_11ea_87c9_448500869c0brow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7401df6e_8c7b_11ea_87c9_448500869c0brow0_col2 {
#             text-align:  left;
#         }    #T_7401df6e_8c7b_11ea_87c9_448500869c0brow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7401df6e_8c7b_11ea_87c9_448500869c0brow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7401df6e_8c7b_11ea_87c9_448500869c0brow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7401df6e_8c7b_11ea_87c9_448500869c0brow0_col6 {
#             background-color:  yellow;
# ...

# %%
lgbm = create_model('lightgbm')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.9091  0.0  0.9167  0.9273  0.9076  0.8625
# 1       0.9091  0.0  0.9167  0.9273  0.9076  0.8625
# 2       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 3       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 4       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 5       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 6       0.9000  0.0  0.8889  0.9250  0.8971  0.8485
# 7       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 8       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 9       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# Mean    0.9718  0.0  0.9722  0.9780  0.9712  0.9573
# SD      0.0431  0.0  0.0430  0.0337  0.0440  0.0653

# %%
tuned_lgbm = tune_model('lightgbm')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.9091  0.0  0.9167  0.9273  0.9076  0.8625
# 1       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 2       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 3       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 4       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 5       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 6       0.9000  0.0  0.8889  0.9250  0.8971  0.8485
# 7       0.9000  0.0  0.8889  0.9250  0.8971  0.8485
# 8       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# 9       1.0000  0.0  1.0000  1.0000  1.0000  1.0000
# Mean    0.9709  0.0  0.9694  0.9777  0.9702  0.9559
# SD      0.0445  0.0  0.0472  0.0340  0.0456  0.0674

# %%
tuned_lgbm.get_params
# Out:
# <bound method BaseEstimator.get_params of OneVsRestClassifier(estimator=LGBMClassifier(boosting_type='gbdt',
#                                              class_weight=None,
#                                              colsample_bytree=1.0,
#                                              importance_type='split',
#                                              learning_rate=0.5, max_depth=70,
#                                              min_child_samples=20,
#                                              min_child_weight=0.001,
#                                              min_split_gain=0.7,
#                                              n_estimators=10, n_jobs=-1,
#                                              num_leaves=150, objective=None,
#                                              random_state=1739, reg_alpha=0.1,
#                                              reg_lambda=0.8, silent=True,
#                                              subsample=1.0,
# ...

# %%
plot_model(tuned_lgbm)
